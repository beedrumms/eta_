# %% [markdown]
# <a href="https://colab.research.google.com/github/beedrumms/eta_/blob/main/absentee_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting google colab on drive 
from google.colab import drive, files
import os
drive.mount("/content/drive")

import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt
import statistics as stats
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Ontario’s chief health officer estimates that 20-30% of employees could be absent from work at the beginning of February.

# %% [markdown]
# -	In a normal year, 6% of staff are typically absent at any given time.
# -	In December, when 10% of staff were absent, 50 out of Ontario’s 5,000 schools were closed due to staff absences.
# -	Teacher absences can be covered using substitute teachers. There are many potential substitute teachers (approximately 40% the number of regular teachers), but it is unclear whether any given absence could be covered by a substitute.
# estimate of the number of schools that might be closed at the beginning of February due to staff absences

# %% [markdown]
# ##estimate of the number of schools that might be closed at the beginning of February due to staff absences

# %%
# things we know 
nTeachers = 150000
nSubstitues = nTeachers *.40
nOntario_schools = 5000
nSick_avg = nTeachers*.06
avg_teacher_per_school = nTeachers/nOntario_schools

print("Approximate number of teachers:", nTeachers, '\n', "Number of substitutes:", nSubstitues, '\n', "Number of schools in Ontario:", nOntario_schools, '\n', 
      "Average number of teachers sick on any day:", nSick_avg, '\n', "Averge number of teachers per school:", avg_teacher_per_school)
# Out:
# Approximate number of teachers: 150000
#  Number of substitutes: 60000.0
#  Number of schools in Ontario: 5000
#  Average number of teachers sick on any day: 9000.0
#  Averge number of teachers per school: 30.0

# %% [markdown]
# #Linear Approach
# - dependent variable = school closures
# - independent variables = staff sick, substitutions

# %%
# We know that for a .04 (4%) increase in teacher illness increased the # of closures from 0 - 50 (0% - 1%)
(nTeachers*.10 - nSick_avg) == nTeachers * .04

s = nTeachers * .04

nTeachers / s # 25 intervals to get through the entire population of teachers 

# that means that if this was a linear relationship, only 25% of schools would close if the entire teacher pop was sick
# Out:
# 25.0

# %%
print("20% of teachers:", nTeachers*.20, '\n', "30% of teachers:", nTeachers*.30)

# if 4% = 1% closures linearly - than 1% acount for 0.25% (.0025) in closures
# so every 1% increase

print("10% more accounts for", 10 * 0.0025,"% closures")
# first 10% acount for 1% second 10% acount for 2.5% 
print("schools closed for 20%:", nOntario_schools * 0.035)

print("20% more accounts for", 20 * 0.0025,"% closures")
# first 10% acount for 1% second 10% acount for 2.5% 
print("schools closed for 30%:", nOntario_schools * 0.05)
# Out:
# 20% of teachers: 30000.0
#  30% of teachers: 45000.0
# 10% more accounts for 0.025 % closures
# schools closed for 20%: 175.00000000000003
# 20% more accounts for 0.05 % closures
# schools closed for 30%: 250.0

# %% [markdown]
# #Simulation
# ####Things we assume:
# - when there are 6% absences, 100% of positions are filled with substitutes
# - the probability of finding a sub when you are sick does not change
# - the probability of finding a sub is .55
# - everything is equal oportunity (equal chance of getting sick)
# - evenly distributed (the averge # of teachers per school is the same)
# - variables are normaly distributed
# - if 6% sick is the average, and the dist is normal -- anything outside the bounds of 3%-9% is not normal and therefore a strain

# %%
def closures_simulation(sick_rate):
  nSchools = [0] * 5000
  supply_pool = 150000 * .40
  closures = 0
  pReplacement = .55

  sick_rate_T = int(150000 * sick_rate)
  sick_rate_S = int(60000 * sick_rate)

  supply_pool_left = supply_pool - sick_rate_S

  for i in range(0, sick_rate_T):
    a = (np.random.randint(100))/100
    if a > pReplacement or supply_pool_left == 0:
      rand_school = (np.random.randint(5000)) # if a sub cannot be find - absence recorded at school 
      nSchools[rand_school] += 1  
    elif a < pReplacement: # if a sub is found, -1 from the sub pool
      supply_pool_left -= 1
         
  for i in nSchools:
    if i > 4: # 0.1333 of the staff at each school 
      closures += 1

  # fin = [closures, closures/5000, supply_pool_left, supply_pool_left/60000, sick_rate_T, sick_rate_T/150000] # for more info :) 
  fin = closures

  return fin

# %%
closures_simulation(.10) # this is working and is pretty close to the given values
# Out:
# 69

# %%
def trials(n,sick_rate):
  lst = []
  for i in range(0,n):
    j = closures_simulation(sick_rate)
    lst.append(j)
  return lst

# %%
#RUNNING THE SIMULATION
ten_df = trials(10000, .10)
twenty_df = trials(10000, .20)
thirty_df = trials(10000, .30)

# %%
print("Avg closures when 10% of teachers are sick:", stats.mean(ten_df))
print("Avg closures when 20% of teachers are sick:", stats.mean(twenty_df))
print("Avg closures when 30% of teachers are sick:", stats.mean(thirty_df))
# Out:
# Avg closures when 10% of teachers are sick: 56.5554
# Avg closures when 20% of teachers are sick: 641.3786
# Avg closures when 30% of teachers are sick: 1816.9549

# %%
ten = list(ten_df)
twenty = list(twenty_df)
thirty = list(thirty_df)

df = pd.DataFrame(zip(ten, twenty, thirty))
df.columns = ["10%", "20%", "30%"]

# %%
fig = go.Figure(data=[go.Histogram(x=df['10%'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a49ce212-a4d5-463c-96b2-deab699f7978" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a49ce212-a4d5-463c-96b2-deab699f7978")) {
#                     Plotly.newPlot(
#                         'a49ce212-a4d5-463c-96b2-deab699f7978',
#                         [{"type": "histogram", "x": [61, 50, 51, 54, 71, 57, 66, 64, 64, 52, 59, 57, 56, 53, 62, 55, 48, 50, 57, 38, 53, 55, 62, 65, 49, 56, 64, 70, 57, 68, 59, 65, 63, 62, 47, 55, 49, 47, 49, 47, 65, 61, 56, 51, 49, 58, 61, 65, 55, 55, 53, 55, 51, 62, 67, 56, 46, 50, 61, 55, 45, 73, 48, 54, 49, 58, 48, 73, 68, 48, 49, 50, 57, 53, 51, 47, 58, 53, 62, 53, 55, 60, 65, 58, 41, 46, 68, 47, 56, 55, 56, 64, 45, 59, 52, 50, 54, 62, 71, 53, 58, 59, 54, 50, 48, 56, 51, 50, 52, 63, 53, 52, 48, 62, 53, 63, 66, 48, 65, 58, 54, 54, 49, 58, 66, 41, 50, 60, 64, 57, 55, 56, 65, 68, 62, 48, 48, 62, 55, 63, 62, 63, 58, 57, 63, 60, 50, 54, 64, 55, 56, 50, 44, 43, 56, 66, 51, 55, 39, 48, 55, 55, 53, 62, 57, 53, 54, 56, 62, 70, 53, 41, 51, 49, 61, 48, 61, 58, 59, 61, 54, 69, 43, 42, 65, 49, 47, 50, 55, 71, 67, 51, 60, 58, 53, 56, 62, 59, 52, 41, 64, 43, 54, 53, 62, 50, 45, 48, 54, 59, 51, 54, 57, 71, 54, 61, 56, 52, 55, 53, 65, 49, 56, 52, 51, 54, 61, 48, 51, 69, 50, 56, 65, 69, 56, 53, 47, 44, 65, 54, 54, 56, 65, 47, 62, 53, 57, 39, 63, 46, 67, 61, 54, 61, 61, 45, 57, 57, 52, 52, 57, 41, 63, 62, 50, 57, 59, 50, 67, 62, 49, 53, 63, 64, 48, 67, 57, 55, 35, 52, 50, 60, 67, 44, 56, 68, 52, 72, 56, 54, 50, 52, 60, 57, 58, 60, 56, 56, 59, 60, 64, 61, 71, 67, 62, 56, 54, 56, 48, 64, 51, 66, 62, 52, 59, 50, 54, 62, 48, 48, 64, 51, 57, 61, 70, 66, 49, 52, 54, 49, 46, 58, 48, 45, 58, 43, 50, 52, 68, 55, 54, 54, 58, 57, 58, 54, 50, 58, 54, 63, 42, 49, 55, 73, 53, 70, 61, 54, 57, 59, 57, 49, 55, 56, 56, 54, 58, 56, 62, 39, 60, 71, 60, 68, 75, 63, 60, 51, 59, 54, 64, 52, 65, 59, 57, 62, 46, 57, 61, 63, 57, 50, 54, 61, 49, 62, 49, 53, 57, 45, 50, 66, 46, 63, 58, 56, 64, 50, 64, 48, 53, 55, 53, 41, 41, 61, 55, 57, 55, 54, 52, 61, 51, 60, 56, 57, 47, 48, 58, 60, 67, 58, 55, 57, 54, 55, 58, 74, 56, 66, 64, 47, 60, 57, 41, 77, 60, 60, 47, 54, 72, 68, 58, 56, 63, 57, 54, 56, 68, 53, 53, 59, 48, 65, 60, 54, 49, 59, 49, 52, 64, 60, 66, 58, 58, 55, 62, 62, 65, 53, 53, 63, 54, 64, 56, 49, 61, 49, 56, 58, 56, 56, 54, 61, 65, 53, 60, 64, 56, 65, 65, 48, 64, 53, 54, 52, 59, 64, 62, 60, 42, 51, 56, 57, 74, 54, 60, 62, 59, 52, 45, 50, 56, 51, 39, 56, 50, 66, 64, 52, 61, 48, 59, 56, 55, 61, 45, 70, 42, 56, 49, 65, 46, 50, 49, 50, 50, 58, 44, 51, 65, 54, 50, 59, 57, 67, 53, 59, 53, 66, 56, 51, 60, 66, 56, 52, 47, 49, 53, 57, 46, 45, 59, 57, 39, 50, 61, 50, 62, 73, 66, 69, 61, 54, 55, 55, 53, 62, 57, 65, 49, 76, 67, 59, 51, 55, 50, 64, 55, 46, 51, 55, 56, 61, 74, 68, 60, 72, 64, 53, 68, 49, 69, 46, 51, 46, 52, 47, 77, 54, 56, 63, 45, 59, 56, 71, 51, 55, 59, 56, 52, 59, 55, 54, 69, 46, 48, 51, 62, 49, 55, 37, 48, 61, 61, 63, 60, 67, 53, 58, 53, 59, 56, 54, 66, 61, 50, 55, 56, 52, 55, 60, 64, 53, 56, 65, 65, 63, 41, 66, 59, 64, 53, 65, 59, 60, 51, 55, 44, 73, 59, 56, 66, 55, 58, 52, 50, 54, 51, 47, 49, 48, 53, 53, 51, 55, 54, 45, 71, 47, 43, 60, 55, 39, 61, 59, 61, 67, 59, 60, 63, 76, 46, 65, 62, 51, 67, 59, 51, 46, 58, 56, 57, 51, 48, 49, 61, 47, 47, 59, 62, 62, 65, 63, 55, 47, 53, 44, 69, 62, 43, 59, 53, 55, 59, 70, 46, 50, 64, 56, 35, 66, 59, 55, 78, 59, 56, 43, 56, 58, 61, 59, 54, 66, 69, 70, 53, 62, 56, 63, 73, 48, 55, 57, 74, 48, 56, 58, 65, 63, 59, 66, 61, 51, 55, 61, 71, 62, 54, 68, 60, 59, 58, 53, 52, 66, 62, 43, 53, 61, 61, 66, 52, 46, 67, 61, 61, 48, 60, 66, 65, 68, 63, 63, 53, 56, 43, 49, 67, 55, 57, 44, 57, 51, 57, 63, 79, 45, 44, 71, 52, 60, 48, 58, 46, 70, 61, 59, 57, 58, 50, 57, 41, 62, 50, 62, 58, 56, 68, 53, 72, 66, 63, 62, 55, 51, 48, 65, 55, 63, 51, 60, 50, 64, 55, 43, 54, 50, 61, 63, 50, 49, 56, 62, 59, 46, 47, 61, 50, 53, 69, 41, 65, 64, 67, 47, 58, 57, 54, 55, 64, 64, 56, 50, 59, 57, 53, 60, 58, 52, 45, 46, 47, 63, 64, 58, 66, 55, 47, 53, 53, 52, 73, 56, 55, 49, 56, 47, 66, 53, 60, 43, 55, 54, 54, 53, 68, 51, 44, 59, 84, 65, 54, 59, 54, 58, 48, 49, 60, 59, 57, 55, 66, 55, 61, 65, 50, 43, 69, 69, 54, 56, 65, 59, 42, 54, 54, 45, 55, 59, 64, 62, 60, 58, 56, 49, 49, 57, 62, 62, 61, 63, 59, 54, 54, 73, 56, 47, 57, 55, 57, 68, 51, 52, 66, 52, 62, ...

# %%
fig = go.Figure(data=[go.Histogram(x=df['20%'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="827d0b17-da97-44cf-8f0d-c903e87d5cbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("827d0b17-da97-44cf-8f0d-c903e87d5cbd")) {
#                     Plotly.newPlot(
#                         '827d0b17-da97-44cf-8f0d-c903e87d5cbd',
#                         [{"type": "histogram", "x": [595, 634, 639, 642, 655, 634, 675, 634, 640, 659, 612, 636, 641, 650, 613, 625, 622, 626, 606, 628, 650, 676, 651, 658, 623, 664, 635, 654, 603, 623, 667, 678, 646, 644, 594, 686, 654, 627, 673, 613, 659, 631, 603, 588, 600, 625, 667, 655, 617, 661, 655, 636, 646, 664, 625, 617, 633, 634, 681, 652, 654, 637, 617, 665, 675, 637, 649, 648, 616, 627, 639, 607, 631, 663, 647, 659, 622, 650, 655, 649, 640, 647, 656, 702, 628, 628, 620, 650, 607, 623, 661, 620, 645, 638, 638, 642, 595, 648, 628, 622, 637, 667, 615, 612, 649, 667, 648, 628, 619, 611, 668, 648, 642, 640, 667, 651, 639, 618, 687, 653, 653, 684, 650, 605, 610, 624, 620, 646, 664, 598, 673, 645, 675, 647, 631, 647, 648, 667, 647, 648, 648, 645, 669, 670, 618, 637, 646, 646, 670, 647, 637, 660, 640, 649, 632, 671, 631, 638, 646, 630, 626, 660, 636, 656, 636, 614, 619, 622, 659, 677, 644, 659, 618, 640, 652, 658, 624, 608, 643, 661, 598, 641, 650, 608, 653, 623, 619, 623, 656, 643, 658, 641, 639, 597, 620, 676, 607, 605, 653, 639, 645, 640, 634, 629, 661, 633, 607, 611, 634, 615, 662, 663, 669, 656, 634, 642, 658, 652, 612, 641, 661, 647, 652, 603, 665, 625, 615, 610, 651, 650, 592, 616, 674, 638, 651, 619, 640, 652, 636, 637, 619, 648, 656, 639, 645, 592, 665, 658, 648, 626, 648, 634, 660, 681, 662, 621, 669, 650, 650, 644, 632, 626, 679, 605, 642, 651, 691, 640, 635, 637, 665, 657, 583, 625, 639, 615, 647, 605, 675, 633, 677, 639, 596, 661, 627, 643, 644, 692, 604, 643, 649, 609, 631, 642, 597, 655, 643, 620, 639, 626, 694, 642, 663, 622, 629, 597, 658, 618, 609, 661, 650, 591, 623, 632, 651, 655, 654, 657, 666, 656, 625, 686, 603, 631, 678, 668, 644, 628, 659, 643, 652, 625, 637, 678, 637, 608, 642, 616, 643, 616, 686, 621, 629, 655, 667, 622, 659, 612, 640, 659, 671, 666, 687, 629, 629, 604, 650, 667, 654, 632, 642, 633, 649, 659, 636, 638, 626, 638, 612, 641, 672, 613, 635, 620, 603, 651, 673, 676, 627, 603, 644, 648, 635, 643, 636, 597, 630, 649, 633, 643, 611, 666, 683, 637, 658, 619, 648, 668, 647, 665, 649, 660, 622, 633, 642, 628, 652, 638, 632, 665, 654, 633, 640, 662, 638, 634, 622, 620, 646, 578, 609, 620, 634, 611, 606, 694, 633, 644, 638, 658, 686, 626, 640, 645, 615, 653, 634, 655, 617, 671, 661, 651, 672, 630, 620, 642, 664, 643, 636, 677, 656, 610, 641, 640, 632, 674, 643, 639, 619, 643, 618, 643, 640, 649, 645, 669, 621, 704, 637, 645, 611, 642, 628, 630, 650, 669, 624, 653, 610, 632, 665, 626, 624, 658, 645, 649, 651, 670, 637, 623, 647, 607, 620, 665, 632, 639, 625, 657, 635, 626, 657, 622, 631, 635, 651, 625, 670, 661, 667, 628, 689, 674, 632, 667, 635, 642, 662, 654, 645, 653, 635, 637, 633, 621, 654, 616, 661, 623, 604, 642, 634, 637, 632, 626, 603, 652, 643, 639, 624, 641, 652, 603, 640, 654, 634, 646, 648, 656, 667, 655, 644, 638, 616, 613, 679, 639, 679, 656, 675, 660, 635, 605, 657, 653, 648, 594, 627, 632, 648, 635, 615, 624, 705, 631, 621, 610, 695, 642, 620, 659, 661, 639, 619, 616, 659, 664, 622, 628, 608, 628, 640, 634, 623, 602, 644, 657, 626, 655, 636, 624, 643, 632, 614, 635, 631, 636, 639, 648, 657, 624, 650, 653, 684, 619, 633, 603, 658, 660, 621, 621, 589, 678, 631, 608, 638, 629, 657, 649, 614, 634, 641, 666, 608, 626, 638, 647, 636, 671, 689, 635, 643, 630, 617, 638, 624, 631, 662, 652, 647, 657, 620, 639, 681, 664, 660, 640, 647, 656, 633, 609, 644, 658, 674, 635, 603, 626, 622, 654, 632, 670, 620, 653, 660, 623, 611, 664, 641, 623, 651, 667, 679, 642, 666, 649, 689, 618, 646, 671, 605, 675, 619, 677, 662, 650, 651, 651, 642, 666, 636, 686, 657, 654, 617, 639, 659, 617, 655, 664, 654, 600, 670, 615, 600, 655, 627, 665, 633, 644, 635, 673, 650, 646, 666, 625, 665, 656, 627, 629, 695, 658, 605, 628, 641, 635, 659, 674, 614, 665, 671, 650, 649, 646, 650, 658, 656, 659, 646, 625, 630, 665, 607, 619, 622, 657, 623, 622, 687, 619, 637, 648, 633, 633, 624, 612, 633, 609, 624, 630, 649, 638, 657, 633, 662, 627, 652, 646, 643, 652, 664, 618, 676, 620, 644, 619, 679, 653, 653, 642, 631, 63 ...

# %%
fig = go.Figure(data=[go.Histogram(x=df['30%'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="40c1e963-7473-4767-aa92-049faed67965" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40c1e963-7473-4767-aa92-049faed67965")) {
#                     Plotly.newPlot(
#                         '40c1e963-7473-4767-aa92-049faed67965',
#                         [{"type": "histogram", "x": [1846, 1843, 1819, 1865, 1806, 1767, 1821, 1759, 1826, 1838, 1828, 1809, 1744, 1861, 1784, 1825, 1867, 1852, 1860, 1825, 1758, 1801, 1808, 1803, 1814, 1815, 1836, 1821, 1770, 1819, 1829, 1836, 1798, 1787, 1779, 1834, 1811, 1837, 1828, 1803, 1820, 1796, 1840, 1790, 1872, 1781, 1808, 1773, 1782, 1827, 1844, 1827, 1754, 1870, 1790, 1828, 1812, 1821, 1778, 1766, 1833, 1805, 1743, 1863, 1889, 1835, 1816, 1873, 1720, 1834, 1807, 1796, 1839, 1770, 1855, 1835, 1790, 1789, 1815, 1814, 1818, 1802, 1791, 1895, 1783, 1773, 1821, 1845, 1858, 1824, 1832, 1816, 1779, 1758, 1821, 1800, 1823, 1782, 1813, 1819, 1906, 1823, 1809, 1864, 1805, 1775, 1840, 1781, 1809, 1818, 1831, 1791, 1800, 1840, 1833, 1781, 1847, 1798, 1841, 1757, 1834, 1779, 1813, 1801, 1863, 1827, 1805, 1824, 1784, 1834, 1774, 1814, 1863, 1804, 1857, 1863, 1823, 1777, 1820, 1826, 1825, 1817, 1795, 1840, 1807, 1789, 1838, 1783, 1809, 1763, 1842, 1787, 1822, 1824, 1793, 1759, 1808, 1764, 1834, 1838, 1821, 1793, 1824, 1834, 1801, 1820, 1788, 1835, 1776, 1792, 1813, 1762, 1766, 1880, 1820, 1822, 1839, 1851, 1838, 1801, 1834, 1866, 1827, 1821, 1842, 1794, 1763, 1849, 1802, 1832, 1774, 1819, 1842, 1847, 1813, 1815, 1763, 1840, 1763, 1809, 1790, 1757, 1864, 1825, 1802, 1854, 1867, 1831, 1767, 1810, 1790, 1828, 1826, 1806, 1808, 1822, 1818, 1802, 1821, 1792, 1829, 1820, 1821, 1833, 1788, 1825, 1790, 1805, 1787, 1852, 1857, 1862, 1833, 1854, 1842, 1810, 1811, 1815, 1796, 1800, 1865, 1797, 1824, 1827, 1840, 1827, 1875, 1820, 1809, 1846, 1767, 1785, 1840, 1835, 1813, 1783, 1789, 1817, 1842, 1816, 1768, 1786, 1811, 1820, 1764, 1824, 1871, 1821, 1767, 1792, 1841, 1829, 1774, 1803, 1850, 1869, 1790, 1820, 1798, 1868, 1814, 1876, 1839, 1831, 1809, 1806, 1826, 1771, 1813, 1789, 1760, 1802, 1803, 1827, 1813, 1820, 1817, 1832, 1825, 1793, 1779, 1856, 1856, 1767, 1875, 1835, 1788, 1799, 1803, 1842, 1846, 1854, 1826, 1804, 1814, 1822, 1809, 1807, 1846, 1789, 1832, 1820, 1882, 1803, 1810, 1811, 1818, 1837, 1771, 1855, 1826, 1796, 1851, 1765, 1813, 1799, 1821, 1757, 1843, 1807, 1828, 1835, 1801, 1793, 1802, 1763, 1838, 1813, 1821, 1857, 1858, 1789, 1796, 1809, 1810, 1807, 1816, 1844, 1820, 1809, 1766, 1840, 1792, 1787, 1863, 1811, 1832, 1761, 1792, 1847, 1875, 1850, 1794, 1816, 1827, 1825, 1783, 1768, 1816, 1780, 1793, 1820, 1805, 1857, 1859, 1867, 1840, 1808, 1799, 1840, 1841, 1825, 1827, 1824, 1824, 1830, 1785, 1836, 1828, 1885, 1841, 1860, 1758, 1811, 1815, 1828, 1802, 1798, 1886, 1788, 1766, 1830, 1808, 1827, 1824, 1794, 1822, 1808, 1790, 1824, 1813, 1845, 1817, 1835, 1796, 1815, 1766, 1799, 1836, 1743, 1803, 1829, 1828, 1798, 1789, 1827, 1862, 1813, 1843, 1806, 1741, 1834, 1838, 1862, 1775, 1824, 1812, 1770, 1820, 1865, 1826, 1835, 1793, 1772, 1769, 1848, 1792, 1826, 1802, 1810, 1820, 1849, 1833, 1821, 1822, 1811, 1809, 1796, 1828, 1839, 1785, 1846, 1844, 1783, 1835, 1887, 1837, 1820, 1798, 1825, 1812, 1802, 1825, 1847, 1788, 1791, 1840, 1809, 1840, 1808, 1780, 1801, 1866, 1801, 1790, 1861, 1833, 1787, 1808, 1797, 1817, 1858, 1824, 1815, 1758, 1813, 1788, 1796, 1792, 1724, 1850, 1790, 1836, 1817, 1786, 1810, 1769, 1830, 1804, 1771, 1740, 1825, 1804, 1831, 1883, 1785, 1805, 1815, 1836, 1792, 1789, 1809, 1826, 1796, 1786, 1824, 1831, 1821, 1785, 1842, 1786, 1819, 1827, 1816, 1814, 1856, 1839, 1803, 1791, 1815, 1784, 1793, 1773, 1798, 1831, 1840, 1796, 1815, 1851, 1818, 1802, 1788, 1857, 1771, 1831, 1791, 1823, 1830, 1849, 1868, 1802, 1784, 1806, 1806, 1774, 1859, 1848, 1809, 1817, 1814, 1834, 1797, 1828, 1750, 1824, 1769, 1901, 1831, 1861, 1866, 1810, 1857, 1801, 1819, 1834, 1793, 1849, 1768, 1766, 1824, 1821, 1798, 1853, 1828, 1801, 1818, 1815, 1854, 1817, 1791, 1754, 1871, 1855, 1811, 1778, 1865, 1846, 1777, 1822, 1838, 1809, 1771, 1828, 1813, 1808, 1862, 1798, 1893, 1837, 1857, 1851, 1836, 1862, 1815, 1804, 1802, 1818, 1819, 1830, 1822, 1768, 1859, 1825, 1805, 1780, 1812, 1847, 1813, 1765, 1763, 1873, 1841, 1833, 1841, 1788, 1781, 1848, 1793, ...

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Histogram(x=df['10%'], name='10% Sick'))
fig.add_trace(go.Histogram(x=df['20%'], name='20% Sick'))
fig.add_trace(go.Histogram(x=df['30%'], name='30% Sick'))

# Overlay both histograms
fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1eb01fff-5d99-4443-8c3b-1a7f3fd4c35a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1eb01fff-5d99-4443-8c3b-1a7f3fd4c35a")) {
#                     Plotly.newPlot(
#                         '1eb01fff-5d99-4443-8c3b-1a7f3fd4c35a',
#                         [{"name": "10% Sick", "opacity": 0.75, "type": "histogram", "x": [61, 50, 51, 54, 71, 57, 66, 64, 64, 52, 59, 57, 56, 53, 62, 55, 48, 50, 57, 38, 53, 55, 62, 65, 49, 56, 64, 70, 57, 68, 59, 65, 63, 62, 47, 55, 49, 47, 49, 47, 65, 61, 56, 51, 49, 58, 61, 65, 55, 55, 53, 55, 51, 62, 67, 56, 46, 50, 61, 55, 45, 73, 48, 54, 49, 58, 48, 73, 68, 48, 49, 50, 57, 53, 51, 47, 58, 53, 62, 53, 55, 60, 65, 58, 41, 46, 68, 47, 56, 55, 56, 64, 45, 59, 52, 50, 54, 62, 71, 53, 58, 59, 54, 50, 48, 56, 51, 50, 52, 63, 53, 52, 48, 62, 53, 63, 66, 48, 65, 58, 54, 54, 49, 58, 66, 41, 50, 60, 64, 57, 55, 56, 65, 68, 62, 48, 48, 62, 55, 63, 62, 63, 58, 57, 63, 60, 50, 54, 64, 55, 56, 50, 44, 43, 56, 66, 51, 55, 39, 48, 55, 55, 53, 62, 57, 53, 54, 56, 62, 70, 53, 41, 51, 49, 61, 48, 61, 58, 59, 61, 54, 69, 43, 42, 65, 49, 47, 50, 55, 71, 67, 51, 60, 58, 53, 56, 62, 59, 52, 41, 64, 43, 54, 53, 62, 50, 45, 48, 54, 59, 51, 54, 57, 71, 54, 61, 56, 52, 55, 53, 65, 49, 56, 52, 51, 54, 61, 48, 51, 69, 50, 56, 65, 69, 56, 53, 47, 44, 65, 54, 54, 56, 65, 47, 62, 53, 57, 39, 63, 46, 67, 61, 54, 61, 61, 45, 57, 57, 52, 52, 57, 41, 63, 62, 50, 57, 59, 50, 67, 62, 49, 53, 63, 64, 48, 67, 57, 55, 35, 52, 50, 60, 67, 44, 56, 68, 52, 72, 56, 54, 50, 52, 60, 57, 58, 60, 56, 56, 59, 60, 64, 61, 71, 67, 62, 56, 54, 56, 48, 64, 51, 66, 62, 52, 59, 50, 54, 62, 48, 48, 64, 51, 57, 61, 70, 66, 49, 52, 54, 49, 46, 58, 48, 45, 58, 43, 50, 52, 68, 55, 54, 54, 58, 57, 58, 54, 50, 58, 54, 63, 42, 49, 55, 73, 53, 70, 61, 54, 57, 59, 57, 49, 55, 56, 56, 54, 58, 56, 62, 39, 60, 71, 60, 68, 75, 63, 60, 51, 59, 54, 64, 52, 65, 59, 57, 62, 46, 57, 61, 63, 57, 50, 54, 61, 49, 62, 49, 53, 57, 45, 50, 66, 46, 63, 58, 56, 64, 50, 64, 48, 53, 55, 53, 41, 41, 61, 55, 57, 55, 54, 52, 61, 51, 60, 56, 57, 47, 48, 58, 60, 67, 58, 55, 57, 54, 55, 58, 74, 56, 66, 64, 47, 60, 57, 41, 77, 60, 60, 47, 54, 72, 68, 58, 56, 63, 57, 54, 56, 68, 53, 53, 59, 48, 65, 60, 54, 49, 59, 49, 52, 64, 60, 66, 58, 58, 55, 62, 62, 65, 53, 53, 63, 54, 64, 56, 49, 61, 49, 56, 58, 56, 56, 54, 61, 65, 53, 60, 64, 56, 65, 65, 48, 64, 53, 54, 52, 59, 64, 62, 60, 42, 51, 56, 57, 74, 54, 60, 62, 59, 52, 45, 50, 56, 51, 39, 56, 50, 66, 64, 52, 61, 48, 59, 56, 55, 61, 45, 70, 42, 56, 49, 65, 46, 50, 49, 50, 50, 58, 44, 51, 65, 54, 50, 59, 57, 67, 53, 59, 53, 66, 56, 51, 60, 66, 56, 52, 47, 49, 53, 57, 46, 45, 59, 57, 39, 50, 61, 50, 62, 73, 66, 69, 61, 54, 55, 55, 53, 62, 57, 65, 49, 76, 67, 59, 51, 55, 50, 64, 55, 46, 51, 55, 56, 61, 74, 68, 60, 72, 64, 53, 68, 49, 69, 46, 51, 46, 52, 47, 77, 54, 56, 63, 45, 59, 56, 71, 51, 55, 59, 56, 52, 59, 55, 54, 69, 46, 48, 51, 62, 49, 55, 37, 48, 61, 61, 63, 60, 67, 53, 58, 53, 59, 56, 54, 66, 61, 50, 55, 56, 52, 55, 60, 64, 53, 56, 65, 65, 63, 41, 66, 59, 64, 53, 65, 59, 60, 51, 55, 44, 73, 59, 56, 66, 55, 58, 52, 50, 54, 51, 47, 49, 48, 53, 53, 51, 55, 54, 45, 71, 47, 43, 60, 55, 39, 61, 59, 61, 67, 59, 60, 63, 76, 46, 65, 62, 51, 67, 59, 51, 46, 58, 56, 57, 51, 48, 49, 61, 47, 47, 59, 62, 62, 65, 63, 55, 47, 53, 44, 69, 62, 43, 59, 53, 55, 59, 70, 46, 50, 64, 56, 35, 66, 59, 55, 78, 59, 56, 43, 56, 58, 61, 59, 54, 66, 69, 70, 53, 62, 56, 63, 73, 48, 55, 57, 74, 48, 56, 58, 65, 63, 59, 66, 61, 51, 55, 61, 71, 62, 54, 68, 60, 59, 58, 53, 52, 66, 62, 43, 53, 61, 61, 66, 52, 46, 67, 61, 61, 48, 60, 66, 65, 68, 63, 63, 53, 56, 43, 49, 67, 55, 57, 44, 57, 51, 57, 63, 79, 45, 44, 71, 52, 60, 48, 58, 46, 70, 61, 59, 57, 58, 50, 57, 41, 62, 50, 62, 58, 56, 68, 53, 72, 66, 63, 62, 55, 51, 48, 65, 55, 63, 51, 60, 50, 64, 55, 43, 54, 50, 61, 63, 50, 49, 56, 62, 59, 46, 47, 61, 50, 53, 69, 41, 65, 64, 67, 47, 58, 57, 54, 55, 64, 64, 56, 50, 59, 57, 53, 60, 58, 52, 45, 46, 47, 63, 64, 58, 66, 55, 47, 53, 53, 52, 73, 56, 55, 49, 56, 47, 66, 53, 60, 43, 55, 54, 54, 53, 68, 51, 44, 59, 84, 65, 54, 59, 54, 58, 48, 49, 60, 59, 57, 55, 66, 55, 61, 65, 50, 43, 69, 69, 54, 56, 65, 59, 42, 54, 54, 45, 55, 59, 64, 62, 60, 58, 56, 49, 49, 57, 62, 62, 61, 63, 59, 54, 54, 73, 56, 47 ...
